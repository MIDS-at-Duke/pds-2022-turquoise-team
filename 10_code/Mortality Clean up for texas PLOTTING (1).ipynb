# %%
import pandas as pd
df = pd.read_csv('/workspaces/pds-2022-turquoise-team/20_intermediate_files/washington_all_counties.csv')
df = df.drop(['Crude Rate'], axis = 1)
# Out:
# /tmp/ipykernel_31157/137461015.py:2: DtypeWarning: Columns (1,3,6,7,10,11,12,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/workspaces/pds-2022-turquoise-team/20_intermediate_files/washington_all_counties.csv')

# %%
df
# Out:
#        Unnamed: 0   State_x  State Code_x           County_x  County Code_x  \
# 0           241.0  Arkansas           5.0  Benton County, AR         5007.0
# 1           241.0  Arkansas           5.0  Benton County, AR         5007.0
# 2           241.0  Arkansas           5.0  Benton County, AR         5007.0
# 3           241.0  Arkansas           5.0  Benton County, AR         5007.0
# 4           241.0  Arkansas           5.0  Benton County, AR         5007.0
# ...           ...       ...           ...                ...            ...
# 83121         NaN       NaN           NaN                NaN            NaN
# 83122         NaN       NaN           NaN                NaN            NaN
# 83123         NaN       NaN           NaN                NaN            NaN
# 83124         NaN       NaN           NaN                NaN            NaN
# 83125         NaN       NaN           NaN                NaN            NaN
#
#        Year_x                                     Cause of death  \
# 0      2009.0  Accidental poisoning by and exposure to other ...
# 1      2009.0  Accidental poisoning by and exposure to other ...
# 2      2009.0  Accidental poisoning by and exposure to other ...
# 3      2009.0  Accidental poisoning by and exposure to other ...
# 4      2009.0  Accidental poisoning by and exposure to other ...
# ...       ...                                                ...
# 83121     NaN                                                NaN
# 83122     NaN                                                NaN
# 83123     NaN                                                NaN
# 83124     NaN                                                NaN
# 83125     NaN                                                NaN
#
#       Cause of death Code  Deaths  Population_x State_Code    County Name  \
# 0                     X44    12.0      216620.0         AR  Benton County
# 1                     X44    12.0      216620.0         AR  Benton County
# 2                     X44    12.0      216620.0         AR  Benton County
# 3                     X44    12.0      216620.0         AR  Benton County
# 4                     X44    12.0      216620.0         AR  Benton County
# ...                   ...     ...           ...        ...            ...
# 83121                 NaN     5.0           NaN        NaN            NaN
# 83122                 NaN     5.0           NaN        NaN            NaN
# 83123                 NaN     5.0           NaN        NaN            NaN
# 83124                 NaN     5.0           NaN        NaN            NaN
# 83125                 NaN     5.0           NaN        NaN            NaN
#
#        year code combo   State_y  State Code_y             County_y  \
# 0               7016.0  Arkansas             5  Arkansas County, AR
# 1               7016.0  Arkansas             5    Ashley County, AR
# 2               7016.0  Arkansas             5    Baxter County, AR
# 3               7016.0  Arkansas             5    Benton County, AR
# 4               7016.0  Arkansas             5     Boone County, AR
# ...                ...       ...           ...                  ...
# 83121          58062.0   Wyoming            56    Weston County, WY
# 83122          58063.0   Wyoming            56  Washakie County, WY
# 83123          58063.0   Wyoming            56    Weston County, WY
# 83124          58064.0   Wyoming            56    Weston County, WY
# 83125          58065.0   Wyoming            56    Weston County, WY
#
#        County Code_y  Year_y  Year Code Population_y
# 0               5001    2015       2015        18433
# 1               5003    2013       2013        21283
# 2               5005    2011       2011        41536
# 3               5007    2009       2009       216620
# 4               5009    2007       2007        36759
# ...              ...     ...        ...          ...
# 83121          56045    2017       2017         6927
# 83122          56043    2020       2020         7760
# 83123          56045    2018       2018         6967
# 83124          56045    2019       2019         6927
# 83125          56045    2020       2020         6743
#
# [83126 rows x 20 columns]

# %%
we_want_texas = ['Arkansas', 'California', 'Georgia', 'Missouri', 'New York', 'Wyoming']
df_texas = df[df['State_y'].isin(we_want_texas)]


df_texas
# Out:
#        Unnamed: 0   State_x  State Code_x           County_x  County Code_x  \
# 0           241.0  Arkansas           5.0  Benton County, AR         5007.0
# 1           241.0  Arkansas           5.0  Benton County, AR         5007.0
# 2           241.0  Arkansas           5.0  Benton County, AR         5007.0
# 3           241.0  Arkansas           5.0  Benton County, AR         5007.0
# 4           241.0  Arkansas           5.0  Benton County, AR         5007.0
# ...           ...       ...           ...                ...            ...
# 83121         NaN       NaN           NaN                NaN            NaN
# 83122         NaN       NaN           NaN                NaN            NaN
# 83123         NaN       NaN           NaN                NaN            NaN
# 83124         NaN       NaN           NaN                NaN            NaN
# 83125         NaN       NaN           NaN                NaN            NaN
#
#        Year_x                                     Cause of death  \
# 0      2009.0  Accidental poisoning by and exposure to other ...
# 1      2009.0  Accidental poisoning by and exposure to other ...
# 2      2009.0  Accidental poisoning by and exposure to other ...
# 3      2009.0  Accidental poisoning by and exposure to other ...
# 4      2009.0  Accidental poisoning by and exposure to other ...
# ...       ...                                                ...
# 83121     NaN                                                NaN
# 83122     NaN                                                NaN
# 83123     NaN                                                NaN
# 83124     NaN                                                NaN
# 83125     NaN                                                NaN
#
#       Cause of death Code  Deaths  Population_x State_Code    County Name  \
# 0                     X44    12.0      216620.0         AR  Benton County
# 1                     X44    12.0      216620.0         AR  Benton County
# 2                     X44    12.0      216620.0         AR  Benton County
# 3                     X44    12.0      216620.0         AR  Benton County
# 4                     X44    12.0      216620.0         AR  Benton County
# ...                   ...     ...           ...        ...            ...
# 83121                 NaN     5.0           NaN        NaN            NaN
# 83122                 NaN     5.0           NaN        NaN            NaN
# 83123                 NaN     5.0           NaN        NaN            NaN
# 83124                 NaN     5.0           NaN        NaN            NaN
# 83125                 NaN     5.0           NaN        NaN            NaN
#
#        year code combo   State_y  State Code_y             County_y  \
# 0               7016.0  Arkansas             5  Arkansas County, AR
# 1               7016.0  Arkansas             5    Ashley County, AR
# 2               7016.0  Arkansas             5    Baxter County, AR
# 3               7016.0  Arkansas             5    Benton County, AR
# 4               7016.0  Arkansas             5     Boone County, AR
# ...                ...       ...           ...                  ...
# 83121          58062.0   Wyoming            56    Weston County, WY
# 83122          58063.0   Wyoming            56  Washakie County, WY
# 83123          58063.0   Wyoming            56    Weston County, WY
# 83124          58064.0   Wyoming            56    Weston County, WY
# 83125          58065.0   Wyoming            56    Weston County, WY
#
#        County Code_y  Year_y  Year Code Population_y
# 0               5001    2015       2015        18433
# 1               5003    2013       2013        21283
# 2               5005    2011       2011        41536
# 3               5007    2009       2009       216620
# 4               5009    2007       2007        36759
# ...              ...     ...        ...          ...
# 83121          56045    2017       2017         6927
# 83122          56043    2020       2020         7760
# 83123          56045    2018       2018         6967
# 83124          56045    2019       2019         6927
# 83125          56045    2020       2020         6743
#
# [17638 rows x 20 columns]

# %%
df_texas = df_texas.drop(columns = ['State_x', 'County Code_x', 'State Code_x', 'County_x', 'Year_x', 'Population_x'])

# %%
we_want_texas = ['Arkansas', 'California', 'Georgia', 'Missouri', 'New York', 'Wyoming']
df_texas = df[df['State_y'].isin(we_want_texas)]
groupedby_df_texas = df_texas.groupby(["Year_y"]).sum() # we feel that sum is the most accurate function to use
groupedby_df_texas = groupedby_df_texas.reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill='')

groupedby_df_texas['Death Rate'] = (groupedby_df_texas['Deaths']/groupedby_df_texas['Population_x'])*100_000
# Out:
# /tmp/ipykernel_31157/77389039.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
from plotnine import *

we_want_texas = ['Arkansas', 'California', 'Georgia', 'Missouri', 'New York', 'Wyoming']
df_texas = df[df['State_y'].isin(we_want_texas)]
groupedby_df_texas = df_texas.groupby(["Year_y"]).sum() # we feel that sum is the most accurate function to use
groupedby_df_texas = groupedby_df_texas.reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill='')
groupedby_df_texas['Death Rate'] = (groupedby_df_texas['Deaths']/groupedby_df_texas['Population_x'])*100_000
we_want_only_texas = ['Texas']
df_only_texas = df[df['State_y'].isin(we_want_only_texas)]

groupedby_df_only_texas = df_only_texas.groupby(["Year_y"]).sum() 
groupedby_df_only_texas = groupedby_df_only_texas.reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill='')
groupedby_df_only_texas['Death Rate'] = (groupedby_df_only_texas['Deaths']/groupedby_df_only_texas['Population_x'])*100_000

def label_row(row): 
    if row['Year_y'] == 2004:
        return -3
    if row['Year_y'] == 2005: 
        return -2
    if row['Year_y'] == 2006:
        return -1
    if row['Year_y'] == 2007: 
        return 0
    if row['Year_y'] == 2008: 
        return 1
    if row['Year_y'] == 2009: 
        return 2

groupedby_df_only_texas['Years since policy'] = groupedby_df_only_texas.apply (lambda row: label_row(row), axis = 1) 
groupedby_df_texas['Years since policy'] = groupedby_df_texas.apply (lambda row: label_row(row), axis = 1) 

g = (
    ggplot(groupedby_df_only_texas, aes(x="Years since policy", y="Death Rate"))
    + geom_smooth(
        method="lm",
        data=groupedby_df_only_texas[groupedby_df_only_texas["Years since policy"] < 0],
        se=False,
    )
    + geom_smooth(
        method="lm",
        data=groupedby_df_only_texas[groupedby_df_only_texas["Years since policy"] >= 0],
        se=False,
    )
    + geom_vline(xintercept=0, linetype="dashed")
    + geom_text(x=-0.7, y=6.1, label="Policy Change", color="black")
    + labs(title="Pre-Post Model Graph, Effective Policy Intervention: Texas")
)
#g.save("images/prepost_successful.pdf")
print(g)



groupedby_df_only_texas['Policy or Control'] = 'Policy'
groupedby_df_texas['Policy or Control'] = 'Control'
texas_policy_control = pd.concat([groupedby_df_texas, groupedby_df_only_texas])

h = (
    ggplot(
        texas_policy_control,
        aes(x="Years since policy", y="Death Rate", color="Policy or Control"),
    )
    + geom_smooth(
        method="lm", data=texas_policy_control[texas_policy_control["Years since policy"] < 0]
    )
    + geom_smooth(
        method="lm", data=texas_policy_control[texas_policy_control["Years since policy"] >= 0]
    )
    + geom_vline(xintercept=0, linetype="dashed")
    + geom_text(x=-0.7, y=7, label="Policy or Control", color="black")
    + labs(
        title="Diff-in-Diff Model Graph, Effective Policy Intervention: Texas",
        color="Counties in State with Policy Change",
    )
    + theme(legend_position="bottom")
)
#g.save("images/diffindiff_successful.pdf")
print(h)
# Out:
# /tmp/ipykernel_31157/1762530055.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# /tmp/ipykernel_31157/1762530055.py:11: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
groupedby_df_only_texas['Death Rate']
# Out:
# 0     3.077789
# 1     2.986054
# 2     3.081747
# 3     2.991525
# 4     3.079670
# 5     2.982857
# 6     3.102751
# 7     2.977401
# 8     3.062622
# 9     3.002083
# 10    3.174527
# 11    3.022000
# 12    3.084522
# 13    2.994260
# 14    3.092579
# 15    2.987442
# 16    3.080847
# 17    3.033569
# 18    3.085789
# 19    2.981487
# 20    3.083213
# 21    2.996996
# Name: Death Rate, dtype: float64
