# %% [markdown]
# # Florida

# %%
import pandas as pd
df = pd.read_csv('/workspaces/pds-2022-turquoise-team/00_source_data/florida_all_data_all_counties.csv')

# %%
df
# Out:
#        Unnamed: 0  Deaths    State              County  Year  Population  \
# 0               0    12.0  Alabama  Autauga County, AL  1999       42963
# 1               1    11.0  Alabama  Autauga County, AL  2000       43671
# 2               2    10.0  Alabama  Autauga County, AL  2001       44889
# 3               3    10.0  Alabama  Autauga County, AL  2002       45909
# 4               4    11.0  Alabama  Autauga County, AL  2001       44889
# ...           ...     ...      ...                 ...   ...         ...
# 72012       72288     5.0  Wyoming   Weston County, WY  2016        7236
# 72013       72289     5.0  Wyoming   Weston County, WY  2017        6927
# 72014       72290     5.0  Wyoming   Weston County, WY  2018        6967
# 72015       72291     5.0  Wyoming   Weston County, WY  2019        6927
# 72016       72292     5.0  Wyoming   Weston County, WY  2020        6743
#
#            _merge  Death Rate
# 0            both   27.931010
# 1            both   25.188340
# 2            both   22.277173
# 3            both   21.782221
# 4            both   24.504890
# ...           ...         ...
# 72012  right_only   69.098950
# 72013  right_only   72.181319
# 72014  right_only   71.766901
# 72015  right_only   72.181319
# 72016  right_only   74.150971
#
# [72017 rows x 8 columns]

# %%
# FL plot
pre_fl_fit = plotting_chart(
    2010, "blue", fl_policy_pre, "Prescription_Rate", "Year", legend="Florida", alpha=0.05
)
post_fl_fit = plotting_chart(
    2010, "blue", fl_policy_post, "Prescription_Rate", "Year", legend="Florida", alpha=0.05
)
final = pre_fl_fit + post_fl_fit

final.properties(
    title="Pre-Policy VS. Post-Policy of Opioid Regulations on Mortality Rate for Florida"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # FL plot
# ----> 2 pre_fl_fit = plotting_chart(
#       3     2010, "blue", fl_policy_pre, "Prescription_Rate", "Year", legend="Florida", alpha=0.05
#       4 )
#       5 post_fl_fit = plotting_chart(
#       6     2010, "blue", fl_policy_post, "Prescription_Rate", "Year", legend="Florida", alpha=0.05
#       7 )
#       8 final = pre_fl_fit + post_fl_fit
#
# NameError: name 'plotting_chart' is not defined
