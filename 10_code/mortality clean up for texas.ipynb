# %%
import pandas as pd
import numpy as np

# %%
# df_2003 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2003.txt')
# df_2004 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2004.txt')
# df_2005 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2005.txt')
# df_2006 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2006.txt')
# df_2007 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2007.txt')
# df_2008 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2008.txt')
# df_2009 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2009.txt')
# df_2010 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2010.txt')
# df_2011 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2011.txt')
# df_2012 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2012.txt')
# df_2013 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2013.txt')
# df_2014 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2014.txt')
# df_2015 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2015.txt')

# %%
# df_2003.sample(5)

# %%
# vital = pd.concat([df_2007,df_2008,df_2009,df_2010,df_2011,df_2012])
# vital.sample(5)

# %%
# Load the dataset
vital = pd.read_table("../00_source_data/mortality for texas.txt")
vital
# Out:
#                                                   Notes    State  State Code  \
# 0                                                   NaN  Alabama         1.0
# 1                                                   NaN  Alabama         1.0
# 2                                                   NaN  Alabama         1.0
# 3                                                   NaN  Alabama         1.0
# 4                                                   NaN  Alabama         1.0
# ...                                                 ...      ...         ...
# 4163  2019 data. Underlying and multiple cause of de...      NaN         NaN
# 4164  unspecified firearm discharge, ICD-10 code X95...      NaN         NaN
# 4165                                              2020.      NaN         NaN
# 4166  14. Changes to cause of death classification a...      NaN         NaN
# 4167  http://wonder.cdc.gov/wonder/help/ucd.html#ICD...      NaN         NaN
#
#                   County  County Code    Year  Year Code  \
# 0     Baldwin County, AL       1003.0  2004.0     2004.0
# 1     Baldwin County, AL       1003.0  2005.0     2005.0
# 2     Baldwin County, AL       1003.0  2007.0     2007.0
# 3     Baldwin County, AL       1003.0  2008.0     2008.0
# 4     Baldwin County, AL       1003.0  2009.0     2009.0
# ...                  ...          ...     ...        ...
# 4163                 NaN          NaN     NaN        NaN
# 4164                 NaN          NaN     NaN        NaN
# 4165                 NaN          NaN     NaN        NaN
# 4166                 NaN          NaN     NaN        NaN
# 4167                 NaN          NaN     NaN        NaN
#
#                                          Cause of death Cause of death Code  \
# 0     Accidental poisoning by and exposure to other ...                 X44
# 1     Accidental poisoning by and exposure to other ...                 X44
# 2     Accidental poisoning by and exposure to other ...                 X44
# 3     Accidental poisoning by and exposure to other ...                 X44
# 4     Accidental poisoning by and exposure to other ...                 X44
# ...                                                 ...                 ...
# 4163                                                NaN                 NaN
# 4164                                                NaN                 NaN
# 4165                                                NaN                 NaN
# 4166                                                NaN                 NaN
# 4167                                                NaN                 NaN
#
#       Deaths  Population  Crude Rate
# 0       16.0    156266.0  Unreliable
# 1       10.0    162183.0  Unreliable
# 2       15.0    172404.0  Unreliable
# 3       13.0    175827.0  Unreliable
# 4       20.0    179406.0     11.1479
# ...      ...         ...         ...
# 4163     NaN         NaN         NaN
# 4164     NaN         NaN         NaN
# 4165     NaN         NaN         NaN
# 4166     NaN         NaN         NaN
# 4167     NaN         NaN         NaN
#
# [4168 rows x 12 columns]

# %%
# Drop the unnecessary data
vital = vital.drop(["Notes","Year Code"], axis = 1)
vital.sample(5)
# Out:
#                State  State Code                County  County Code    Year  \
# 2492      New Mexico        35.0   Dona Ana County, NM      35013.0  2006.0
# 2812  North Carolina        37.0      Rowan County, NC      37159.0  2008.0
# 1628        Kentucky        21.0  Jefferson County, KY      21111.0  2004.0
# 4032       Wisconsin        55.0       Dane County, WI      55025.0  2006.0
# 1928   Massachusetts        25.0   Plymouth County, MA      25023.0  2009.0
#
#                                          Cause of death Cause of death Code  \
# 2492  Accidental poisoning by and exposure to narcot...                 X42
# 2812  Accidental poisoning by and exposure to narcot...                 X42
# 1628  Accidental poisoning by and exposure to other ...                 X44
# 4032  Accidental poisoning by and exposure to narcot...                 X42
# 1928  Accidental poisoning by and exposure to other ...                 X44
#
#       Deaths  Population  Crude Rate
# 2492    12.0    193701.0  Unreliable
# 2812    24.0    137721.0     17.4265
# 1628    37.0    706828.0      5.2347
# 4032    14.0    465018.0  Unreliable
# 1928    10.0    492738.0  Unreliable

# %%
# Checking the amount of null values
vital.isna().sum()
# Out:
# State                  90
# State Code             90
# County                 90
# County Code            90
# Year                   90
# Cause of death         90
# Cause of death Code    90
# Deaths                 90
# Population             90
# Crude Rate             90
# dtype: int64

# %%
# Checking initial shape (before droppping null values)
vital.shape
# Out:
# (4168, 10)

# %%
# Drop null values
vital.dropna(inplace=True)

# %%
# Checking the shape after dropping null values
vital.shape
# Out:
# (4078, 10)

# %%
# Adding state code 
vital["State_Code"] = vital["County"].str[-2:]
vital["County Name"] = vital["County"].str[:-4]
vital.sort_values("County")
# Out:
#                State  State Code             County  County Code    Year  \
# 1664       Louisiana        22.0  Acadia Parish, LA      22001.0  2007.0
# 1662       Louisiana        22.0  Acadia Parish, LA      22001.0  2005.0
# 1663       Louisiana        22.0  Acadia Parish, LA      22001.0  2006.0
# 1359           Idaho        16.0     Ada County, ID      16001.0  2009.0
# 1358           Idaho        16.0     Ada County, ID      16001.0  2009.0
# ...              ...         ...                ...          ...     ...
# 3437  South Carolina        45.0    York County, SC      45091.0  2008.0
# 3438  South Carolina        45.0    York County, SC      45091.0  2009.0
# 3439  South Carolina        45.0    York County, SC      45091.0  2009.0
# 166          Arizona         4.0    Yuma County, AZ       4027.0  2009.0
# 165          Arizona         4.0    Yuma County, AZ       4027.0  2007.0
#
#                                          Cause of death Cause of death Code  \
# 1664  Poisoning by and exposure to other and unspeci...                 Y14
# 1662  Accidental poisoning by and exposure to other ...                 X44
# 1663  Accidental poisoning by and exposure to other ...                 X44
# 1359  Accidental poisoning by and exposure to other ...                 X44
# 1358  Accidental poisoning by and exposure to narcot...                 X42
# ...                                                 ...                 ...
# 3437  Accidental poisoning by and exposure to other ...                 X44
# 3438  Accidental poisoning by and exposure to narcot...                 X42
# 3439  Accidental poisoning by and exposure to other ...                 X44
# 166   Accidental poisoning by and exposure to other ...                 X44
# 165   Accidental poisoning by and exposure to other ...                 X44
#
#       Deaths  Population  Crude Rate State_Code    County Name
# 1664    12.0     60762.0  Unreliable         LA  Acadia Parish
# 1662    14.0     59524.0  Unreliable         LA  Acadia Parish
# 1663    13.0     60522.0  Unreliable         LA  Acadia Parish
# 1359    17.0    388577.0  Unreliable         ID     Ada County
# 1358    11.0    388577.0  Unreliable         ID     Ada County
# ...      ...         ...         ...        ...            ...
# 3437    20.0    217463.0      9.1970         SC    York County
# 3438    11.0    223616.0  Unreliable         SC    York County
# 3439    14.0    223616.0  Unreliable         SC    York County
# 166     14.0    193714.0  Unreliable         AZ    Yuma County
# 165     15.0    187357.0  Unreliable         AZ    Yuma County
#
# [4078 rows x 12 columns]

# %%
vital.sort_values("County")
# Out:
#         Year      State  State Code             County  County Code  \
# 285   2007.0  Louisiana        22.0  Acadia Parish, LA      22001.0
# 1711  2009.0      Idaho        16.0     Ada County, ID      16001.0
# 3288  2011.0      Idaho        16.0     Ada County, ID      16001.0
# 3289  2011.0      Idaho        16.0     Ada County, ID      16001.0
# 2469  2010.0      Idaho        16.0     Ada County, ID      16001.0
# ...      ...        ...         ...                ...          ...
# 1503  2009.0    Arizona         4.0    Yuma County, AZ       4027.0
# 31    2007.0    Arizona         4.0    Yuma County, AZ       4027.0
# 3061  2011.0    Arizona         4.0    Yuma County, AZ       4027.0
# 3959  2012.0    Arizona         4.0    Yuma County, AZ       4027.0
# 2248  2010.0    Arizona         4.0    Yuma County, AZ       4027.0
#
#                                          Cause of death Cause of death Code  \
# 285   Poisoning by and exposure to other and unspeci...                 Y14
# 1711  Accidental poisoning by and exposure to other ...                 X44
# 3288  Accidental poisoning by and exposure to narcot...                 X42
# 3289  Accidental poisoning by and exposure to other ...                 X44
# 2469  Accidental poisoning by and exposure to other ...                 X44
# ...                                                 ...                 ...
# 1503  Accidental poisoning by and exposure to other ...                 X44
# 31    Accidental poisoning by and exposure to other ...                 X44
# 3061  Accidental poisoning by and exposure to other ...                 X44
# 3959  Accidental poisoning by and exposure to other ...                 X44
# 2248  Accidental poisoning by and exposure to other ...                 X44
#
#       Deaths  Population  Crude Rate State_Code    County Name
# 285     12.0     60762.0  Unreliable         LA  Acadia Parish
# 1711    17.0    388577.0  Unreliable         ID     Ada County
# 3288    12.0    400842.0  Unreliable         ID     Ada County
# 3289    17.0    400842.0  Unreliable         ID     Ada County
# 2469    16.0    392365.0  Unreliable         ID     Ada County
# ...      ...         ...         ...        ...            ...
# 1503    14.0    193714.0  Unreliable         AZ    Yuma County
# 31      15.0    187357.0  Unreliable         AZ    Yuma County
# 3061    18.0    200870.0  Unreliable         AZ    Yuma County
# 3959    30.0    200022.0        15.0         AZ    Yuma County
# 2248    18.0    195751.0  Unreliable         AZ    Yuma County
#
# [4800 rows x 12 columns]

# %%
vital["Year"] = pd.DatetimeIndex(pd.to_datetime(vital["Year"],format="%Y")).year
vital
# Out:
#           State  State Code                County  County Code  Year  \
# 0       Alabama         1.0    Baldwin County, AL       1003.0  2004
# 1       Alabama         1.0    Baldwin County, AL       1003.0  2005
# 2       Alabama         1.0    Baldwin County, AL       1003.0  2007
# 3       Alabama         1.0    Baldwin County, AL       1003.0  2008
# 4       Alabama         1.0    Baldwin County, AL       1003.0  2009
# ...         ...         ...                   ...          ...   ...
# 4073  Wisconsin        55.0   Waukesha County, WI      55133.0  2007
# 4074  Wisconsin        55.0   Waukesha County, WI      55133.0  2008
# 4075  Wisconsin        55.0   Waukesha County, WI      55133.0  2009
# 4076  Wisconsin        55.0   Waukesha County, WI      55133.0  2009
# 4077  Wisconsin        55.0  Winnebago County, WI      55139.0  2007
#
#                                          Cause of death Cause of death Code  \
# 0     Accidental poisoning by and exposure to other ...                 X44
# 1     Accidental poisoning by and exposure to other ...                 X44
# 2     Accidental poisoning by and exposure to other ...                 X44
# 3     Accidental poisoning by and exposure to other ...                 X44
# 4     Accidental poisoning by and exposure to other ...                 X44
# ...                                                 ...                 ...
# 4073  Intentional self-poisoning by and exposure to ...                 X64
# 4074  Accidental poisoning by and exposure to narcot...                 X42
# 4075  Accidental poisoning by and exposure to narcot...                 X42
# 4076  Accidental poisoning by and exposure to other ...                 X44
# 4077  Accidental poisoning by and exposure to narcot...                 X42
#
#       Deaths  Population  Crude Rate State_Code       County Name
# 0       16.0    156266.0  Unreliable         AL    Baldwin County
# 1       10.0    162183.0  Unreliable         AL    Baldwin County
# 2       15.0    172404.0  Unreliable         AL    Baldwin County
# 3       13.0    175827.0  Unreliable         AL    Baldwin County
# 4       20.0    179406.0     11.1479         AL    Baldwin County
# ...      ...         ...         ...        ...               ...
# 4073    10.0    384239.0  Unreliable         WI   Waukesha County
# 4074    16.0    386691.0  Unreliable         WI   Waukesha County
# 4075    13.0    388957.0  Unreliable         WI   Waukesha County
# 4076    11.0    388957.0  Unreliable         WI   Waukesha County
# 4077    13.0    164037.0  Unreliable         WI  Winnebago County
#
# [4078 rows x 12 columns]

# %%
vital["Cause of death"].value_counts()
# Out:
# Accidental poisoning by and exposure to narcotics and psychodysleptics [hallucinogens], not elsewhere classified                                         1532
# Accidental poisoning by and exposure to other and unspecified drugs, medicaments and biological substances                                               1513
# Intentional self-poisoning by and exposure to other and unspecified drugs, medicaments and biological substances                                          306
# Accidental poisoning by and exposure to antiepileptic, sedative-hypnotic, antiparkinsonism and psychotropic drugs, not elsewhere classified               149
# Poisoning by and exposure to other and unspecified drugs, medicaments and biological substances, undetermined intent                                      139
# Poisoning by and exposure to narcotics and psychodysleptics [hallucinogens], not elsewhere classified, undetermined intent                                139
# Mental and behavioural disorders due to multiple drug use and use of other psychoactive substances, harmful use                                           119
# Intentional self-poisoning by and exposure to antiepileptic, sedative-hypnotic, antiparkinsonism and psychotropic drugs, not elsewhere classified          50
# Mental and behavioural disorders due to use of tobacco, unspecified mental and behavioural disorder                                                        42
# Intentional self-poisoning by and exposure to narcotics and psychodysleptics [hallucinogens], not elsewhere classified                                     19
# Mental and behavioural disorders due to use of cocaine, harmful use                                                                                        15
# Mental and behavioural disorders due to use of opioids, harmful use                                                                                        11
# Mental and behavioural disorders due to use of cocaine, unspecified mental and behavioural disorder                                                        11
# Mental and behavioural disorders due to multiple drug use and use of other psychoactive substances, dependence syndrome                                    11
# Mental and behavioural disorders due to use of opioids, unspecified mental and behavioural disorder                                                         5
# Mental and behavioural disorders due to use of opioids, dependence syndrome                                                                                 4
# Mental and behavioural disorders due to multiple drug use and use of other psychoactive substances, unspecified mental and behavioural disorder             4
# Poisoning by and exposure to antiepileptic, sedative-hypnotic, antiparkinsonism and psychotropic drugs, not elsewhere classified, undetermined intent       3
# Mental and behavioural disorders due to use of cocaine, dependence syndrome                                                                                 2
# Accidental poisoning by and exposure to nonopioid analgesics, antipyretics and antirheumatics                                                               1
# Mental and behavioural disorders due to use of other stimulants, including caffeine, unspecified mental and behavioural disorder                            1
# Mental and behavioural disorders due to use of other stimulants, including caffeine, harmful use                                                            1
# Intentional self-poisoning by and exposure to nonopioid analgesics, antipyretics and antirheumatics                                                         1
# Name: Cause of death, dtype: int64

# %%
delete_cause = [
        "Mental and behavioural disorders due to use of tobacco, unspecified mental and behavioural disorder",
        "Mental and behavioural disorders due to use of cocaine, harmful use",
        "Mental and behavioural disorders due to use of cocaine, unspecified mental and behavioural disorder",
        "Intentional self-poisoning by and exposure to nonopioid analgesics, antipyretics and antirheumatics",
        "Accidental poisoning by and exposure to nonopioid analgesics, antipyretics and antirheumatics"
        ]

# %%
combining = [
    "Drug poisonings (overdose) Unintentional (X40-X44)",
    "Drug poisonings (overdose) Suicide (X60-X64)",
    "Drug poisonings (overdose) Undetermined (Y10-Y14)",
    "All other drug-induced causes",
    "Drug poisonings (overdose) Homicide (X85)",
]

# %%
vital_upd = vital[~vital["Cause of death"].isin(delete_cause)]
vital_upd
# Out:
#           State  State Code                County  County Code  Year  \
# 0       Alabama         1.0    Baldwin County, AL       1003.0  2004
# 1       Alabama         1.0    Baldwin County, AL       1003.0  2005
# 2       Alabama         1.0    Baldwin County, AL       1003.0  2007
# 3       Alabama         1.0    Baldwin County, AL       1003.0  2008
# 4       Alabama         1.0    Baldwin County, AL       1003.0  2009
# ...         ...         ...                   ...          ...   ...
# 4073  Wisconsin        55.0   Waukesha County, WI      55133.0  2007
# 4074  Wisconsin        55.0   Waukesha County, WI      55133.0  2008
# 4075  Wisconsin        55.0   Waukesha County, WI      55133.0  2009
# 4076  Wisconsin        55.0   Waukesha County, WI      55133.0  2009
# 4077  Wisconsin        55.0  Winnebago County, WI      55139.0  2007
#
#                                          Cause of death Cause of death Code  \
# 0     Accidental poisoning by and exposure to other ...                 X44
# 1     Accidental poisoning by and exposure to other ...                 X44
# 2     Accidental poisoning by and exposure to other ...                 X44
# 3     Accidental poisoning by and exposure to other ...                 X44
# 4     Accidental poisoning by and exposure to other ...                 X44
# ...                                                 ...                 ...
# 4073  Intentional self-poisoning by and exposure to ...                 X64
# 4074  Accidental poisoning by and exposure to narcot...                 X42
# 4075  Accidental poisoning by and exposure to narcot...                 X42
# 4076  Accidental poisoning by and exposure to other ...                 X44
# 4077  Accidental poisoning by and exposure to narcot...                 X42
#
#       Deaths  Population  Crude Rate State_Code       County Name
# 0       16.0    156266.0  Unreliable         AL    Baldwin County
# 1       10.0    162183.0  Unreliable         AL    Baldwin County
# 2       15.0    172404.0  Unreliable         AL    Baldwin County
# 3       13.0    175827.0  Unreliable         AL    Baldwin County
# 4       20.0    179406.0     11.1479         AL    Baldwin County
# ...      ...         ...         ...        ...               ...
# 4073    10.0    384239.0  Unreliable         WI   Waukesha County
# 4074    16.0    386691.0  Unreliable         WI   Waukesha County
# 4075    13.0    388957.0  Unreliable         WI   Waukesha County
# 4076    11.0    388957.0  Unreliable         WI   Waukesha County
# 4077    13.0    164037.0  Unreliable         WI  Winnebago County
#
# [4008 rows x 12 columns]

# %%
states_control = pd.read_csv("../20_intermediate_files/states_control.csv", index_col=0)
states = list(states_control.States.unique())
states.remove('Alaska')
abbrv = ['CA','NV','NY','TX','HI','IA','KS','ME','MA','MN','MT','NE','ND','OR','SD','VA','WY','AR','GA','MS', 'FL', 'WA']

# %%
vital_upd_2 = vital_upd.loc[vital_upd["State_Code"].isin(abbrv),:]
vital_upd_2
# Out:
#            State  State Code                County  County Code  Year  \
# 167     Arkansas         5.0     Benton County, AR       5007.0  2008
# 168     Arkansas         5.0     Benton County, AR       5007.0  2009
# 169     Arkansas         5.0  Craighead County, AR       5031.0  2008
# 170     Arkansas         5.0  Craighead County, AR       5031.0  2009
# 171     Arkansas         5.0    Garland County, AR       5051.0  2007
# ...          ...         ...                   ...          ...   ...
# 3990  Washington        53.0    Whatcom County, WA      53073.0  2008
# 3991  Washington        53.0    Whatcom County, WA      53073.0  2009
# 3992  Washington        53.0     Yakima County, WA      53077.0  2004
# 3993  Washington        53.0     Yakima County, WA      53077.0  2007
# 3994  Washington        53.0     Yakima County, WA      53077.0  2009
#
#                                          Cause of death Cause of death Code  \
# 167   Accidental poisoning by and exposure to other ...                 X44
# 168   Accidental poisoning by and exposure to other ...                 X44
# 169   Accidental poisoning by and exposure to other ...                 X44
# 170   Accidental poisoning by and exposure to other ...                 X44
# 171   Poisoning by and exposure to other and unspeci...                 Y14
# ...                                                 ...                 ...
# 3990  Accidental poisoning by and exposure to narcot...                 X42
# 3991  Accidental poisoning by and exposure to narcot...                 X42
# 3992  Accidental poisoning by and exposure to other ...                 X44
# 3993  Accidental poisoning by and exposure to other ...                 X44
# 3994  Accidental poisoning by and exposure to other ...                 X44
#
#       Deaths  Population  Crude Rate State_Code       County Name
# 167     11.0    210807.0  Unreliable         AR     Benton County
# 168     12.0    216620.0  Unreliable         AR     Benton County
# 169     13.0     93316.0  Unreliable         AR  Craighead County
# 170     19.0     95482.0  Unreliable         AR  Craighead County
# 171     12.0     94753.0  Unreliable         AR    Garland County
# ...      ...         ...         ...        ...               ...
# 3990    13.0    196708.0  Unreliable         WA    Whatcom County
# 3991    11.0    199865.0  Unreliable         WA    Whatcom County
# 3992    13.0    227280.0  Unreliable         WA     Yakima County
# 3993    14.0    232733.0  Unreliable         WA     Yakima County
# 3994    14.0    239604.0  Unreliable         WA     Yakima County
#
# [1867 rows x 12 columns]

# %%
vital_upd_2.to_csv("../20_intermediate_files/vital_stats_TEXAS_merged.csv", encoding='utf-8')

# %%
vitalx = pd.read_csv('../20_intermediate_files/vital_stats_merged.csv')
