# %%
import pandas as pd
import numpy as np

# %%
# df_2003 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2003.txt')
# df_2004 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2004.txt')
# df_2005 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2005.txt')
# df_2006 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2006.txt')
# df_2007 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2007.txt')
# df_2008 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2008.txt')
# df_2009 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2009.txt')
# df_2010 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2010.txt')
# df_2011 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2011.txt')
# df_2012 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2012.txt')
# df_2013 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2013.txt')
# df_2014 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2014.txt')
# df_2015 = pd.read_table('../00_source_data/US_VITAL_STATISTICS/Underlying Cause of Death, 2015.txt')

# %%
# df_2003.sample(5)

# %%
# vital = pd.concat([df_2007,df_2008,df_2009,df_2010,df_2011,df_2012])
# vital.sample(5)

# %%
# Load the dataset
vital = pd.read_table("../00_source_data/mortality for washington.txt")
vital
# Out:
#                                                   Notes    State  State Code  \
# 0                                                   NaN  Alabama         1.0
# 1                                                   NaN  Alabama         1.0
# 2                                                   NaN  Alabama         1.0
# 3                                                   NaN  Alabama         1.0
# 4                                                   NaN  Alabama         1.0
# ...                                                 ...      ...         ...
# 5347  2019 data. Underlying and multiple cause of de...      NaN         NaN
# 5348  unspecified firearm discharge, ICD-10 code X95...      NaN         NaN
# 5349                                              2020.      NaN         NaN
# 5350  17. Changes to cause of death classification a...      NaN         NaN
# 5351  http://wonder.cdc.gov/wonder/help/ucd.html#ICD...      NaN         NaN
#
#                   County  County Code    Year  Year Code  \
# 0     Baldwin County, AL       1003.0  2009.0     2009.0
# 1     Baldwin County, AL       1003.0  2010.0     2010.0
# 2     Baldwin County, AL       1003.0  2011.0     2011.0
# 3     Baldwin County, AL       1003.0  2011.0     2011.0
# 4     Baldwin County, AL       1003.0  2012.0     2012.0
# ...                  ...          ...     ...        ...
# 5347                 NaN          NaN     NaN        NaN
# 5348                 NaN          NaN     NaN        NaN
# 5349                 NaN          NaN     NaN        NaN
# 5350                 NaN          NaN     NaN        NaN
# 5351                 NaN          NaN     NaN        NaN
#
#                                          Cause of death Cause of death Code  \
# 0     Accidental poisoning by and exposure to other ...                 X44
# 1     Accidental poisoning by and exposure to other ...                 X44
# 2     Accidental poisoning by and exposure to narcot...                 X42
# 3     Accidental poisoning by and exposure to other ...                 X44
# 4     Accidental poisoning by and exposure to other ...                 X44
# ...                                                 ...                 ...
# 5347                                                NaN                 NaN
# 5348                                                NaN                 NaN
# 5349                                                NaN                 NaN
# 5350                                                NaN                 NaN
# 5351                                                NaN                 NaN
#
#       Deaths  Population  Crude Rate
# 0       20.0    179406.0     11.1479
# 1       18.0    182265.0  Unreliable
# 2       10.0    186717.0  Unreliable
# 3       12.0    186717.0  Unreliable
# 4       18.0    190790.0  Unreliable
# ...      ...         ...         ...
# 5347     NaN         NaN         NaN
# 5348     NaN         NaN         NaN
# 5349     NaN         NaN         NaN
# 5350     NaN         NaN         NaN
# 5351     NaN         NaN         NaN
#
# [5352 rows x 12 columns]

# %%
# Drop the unnecessary data
vital = vital.drop(["Notes","Year Code"], axis = 1)
vital.sample(5)
# Out:
#              State  State Code                 County  County Code    Year  \
# 4016  Pennsylvania        42.0       Bucks County, PA      42017.0  2011.0
# 919       Colorado         8.0   Jefferson County, CO       8059.0  2012.0
# 3011    New Jersey        34.0   Middlesex County, NJ      34023.0  2010.0
# 3232      New York        36.0      Monroe County, NY      36055.0  2014.0
# 4186  Pennsylvania        42.0  Montgomery County, PA      42091.0  2010.0
#
#                                          Cause of death Cause of death Code  \
# 4016  Accidental poisoning by and exposure to narcot...                 X42
# 919   Intentional self-poisoning by and exposure to ...                 X64
# 3011  Accidental poisoning by and exposure to other ...                 X44
# 3232  Accidental poisoning by and exposure to narcot...                 X42
# 4186  Accidental poisoning by and exposure to narcot...                 X42
#
#       Deaths  Population  Crude Rate
# 4016    18.0    626854.0  Unreliable
# 919     11.0    545358.0  Unreliable
# 3011    23.0    809858.0      2.8400
# 3232    74.0    749857.0      9.8685
# 4186    36.0    799874.0      4.5007

# %%
# Checking the amount of null values
vital.isna().sum()
# Out:
# State                  103
# State Code             103
# County                 103
# County Code            103
# Year                   103
# Cause of death         103
# Cause of death Code    103
# Deaths                 103
# Population             103
# Crude Rate             103
# dtype: int64

# %%
# Checking initial shape (before droppping null values)
vital.shape
# Out:
# (5352, 10)

# %%
# Drop null values
vital.dropna(inplace=True)

# %%
# Checking the shape after dropping null values
vital.shape
# Out:
# (5249, 10)

# %%
# Adding state code 
vital["State_Code"] = vital["County"].str[-2:]
vital["County Name"] = vital["County"].str[:-4]
vital.sort_values("County")
# Out:
#         State  State Code           County  County Code    Year  \
# 1597    Idaho        16.0   Ada County, ID      16001.0  2013.0
# 1589    Idaho        16.0   Ada County, ID      16001.0  2009.0
# 1590    Idaho        16.0   Ada County, ID      16001.0  2009.0
# 1591    Idaho        16.0   Ada County, ID      16001.0  2010.0
# 1592    Idaho        16.0   Ada County, ID      16001.0  2010.0
# ...       ...         ...              ...          ...     ...
# 237   Arizona         4.0  Yuma County, AZ       4027.0  2011.0
# 238   Arizona         4.0  Yuma County, AZ       4027.0  2012.0
# 239   Arizona         4.0  Yuma County, AZ       4027.0  2013.0
# 240   Arizona         4.0  Yuma County, AZ       4027.0  2014.0
# 235   Arizona         4.0  Yuma County, AZ       4027.0  2009.0
#
#                                          Cause of death Cause of death Code  \
# 1597  Accidental poisoning by and exposure to other ...                 X44
# 1589  Accidental poisoning by and exposure to narcot...                 X42
# 1590  Accidental poisoning by and exposure to other ...                 X44
# 1591  Accidental poisoning by and exposure to narcot...                 X42
# 1592  Accidental poisoning by and exposure to other ...                 X44
# ...                                                 ...                 ...
# 237   Accidental poisoning by and exposure to other ...                 X44
# 238   Accidental poisoning by and exposure to other ...                 X44
# 239   Accidental poisoning by and exposure to other ...                 X44
# 240   Accidental poisoning by and exposure to other ...                 X44
# 235   Accidental poisoning by and exposure to other ...                 X44
#
#       Deaths  Population  Crude Rate State_Code  County Name
# 1597    21.0    416464.0      5.0425         ID   Ada County
# 1589    11.0    388577.0  Unreliable         ID   Ada County
# 1590    17.0    388577.0  Unreliable         ID   Ada County
# 1591    11.0    392365.0  Unreliable         ID   Ada County
# 1592    16.0    392365.0  Unreliable         ID   Ada County
# ...      ...         ...         ...        ...          ...
# 237     18.0    200870.0  Unreliable         AZ  Yuma County
# 238     30.0    200022.0     14.9984         AZ  Yuma County
# 239     19.0    201201.0  Unreliable         AZ  Yuma County
# 240     33.0    203247.0     16.2364         AZ  Yuma County
# 235     14.0    193714.0  Unreliable         AZ  Yuma County
#
# [5249 rows x 12 columns]

# %%
vital.sort_values("County")
# Out:
#         State  State Code           County  County Code    Year  \
# 1597    Idaho        16.0   Ada County, ID      16001.0  2013.0
# 1589    Idaho        16.0   Ada County, ID      16001.0  2009.0
# 1590    Idaho        16.0   Ada County, ID      16001.0  2009.0
# 1591    Idaho        16.0   Ada County, ID      16001.0  2010.0
# 1592    Idaho        16.0   Ada County, ID      16001.0  2010.0
# ...       ...         ...              ...          ...     ...
# 237   Arizona         4.0  Yuma County, AZ       4027.0  2011.0
# 238   Arizona         4.0  Yuma County, AZ       4027.0  2012.0
# 239   Arizona         4.0  Yuma County, AZ       4027.0  2013.0
# 240   Arizona         4.0  Yuma County, AZ       4027.0  2014.0
# 235   Arizona         4.0  Yuma County, AZ       4027.0  2009.0
#
#                                          Cause of death Cause of death Code  \
# 1597  Accidental poisoning by and exposure to other ...                 X44
# 1589  Accidental poisoning by and exposure to narcot...                 X42
# 1590  Accidental poisoning by and exposure to other ...                 X44
# 1591  Accidental poisoning by and exposure to narcot...                 X42
# 1592  Accidental poisoning by and exposure to other ...                 X44
# ...                                                 ...                 ...
# 237   Accidental poisoning by and exposure to other ...                 X44
# 238   Accidental poisoning by and exposure to other ...                 X44
# 239   Accidental poisoning by and exposure to other ...                 X44
# 240   Accidental poisoning by and exposure to other ...                 X44
# 235   Accidental poisoning by and exposure to other ...                 X44
#
#       Deaths  Population  Crude Rate State_Code  County Name
# 1597    21.0    416464.0      5.0425         ID   Ada County
# 1589    11.0    388577.0  Unreliable         ID   Ada County
# 1590    17.0    388577.0  Unreliable         ID   Ada County
# 1591    11.0    392365.0  Unreliable         ID   Ada County
# 1592    16.0    392365.0  Unreliable         ID   Ada County
# ...      ...         ...         ...        ...          ...
# 237     18.0    200870.0  Unreliable         AZ  Yuma County
# 238     30.0    200022.0     14.9984         AZ  Yuma County
# 239     19.0    201201.0  Unreliable         AZ  Yuma County
# 240     33.0    203247.0     16.2364         AZ  Yuma County
# 235     14.0    193714.0  Unreliable         AZ  Yuma County
#
# [5249 rows x 12 columns]

# %%
vital["Year"] = pd.DatetimeIndex(pd.to_datetime(vital["Year"],format="%Y")).year
vital
# Out:
#           State  State Code                County  County Code  Year  \
# 0       Alabama         1.0    Baldwin County, AL       1003.0  2009
# 1       Alabama         1.0    Baldwin County, AL       1003.0  2010
# 2       Alabama         1.0    Baldwin County, AL       1003.0  2011
# 3       Alabama         1.0    Baldwin County, AL       1003.0  2011
# 4       Alabama         1.0    Baldwin County, AL       1003.0  2012
# ...         ...         ...                   ...          ...   ...
# 5244  Wisconsin        55.0  Winnebago County, WI      55139.0  2012
# 5245  Wisconsin        55.0  Winnebago County, WI      55139.0  2014
# 5246  Wisconsin        55.0  Winnebago County, WI      55139.0  2014
# 5247    Wyoming        56.0    Laramie County, WY      56021.0  2012
# 5248    Wyoming        56.0    Natrona County, WY      56025.0  2013
#
#                                          Cause of death Cause of death Code  \
# 0     Accidental poisoning by and exposure to other ...                 X44
# 1     Accidental poisoning by and exposure to other ...                 X44
# 2     Accidental poisoning by and exposure to narcot...                 X42
# 3     Accidental poisoning by and exposure to other ...                 X44
# 4     Accidental poisoning by and exposure to other ...                 X44
# ...                                                 ...                 ...
# 5244  Accidental poisoning by and exposure to narcot...                 X42
# 5245  Accidental poisoning by and exposure to narcot...                 X42
# 5246  Accidental poisoning by and exposure to other ...                 X44
# 5247  Accidental poisoning by and exposure to other ...                 X44
# 5248  Accidental poisoning by and exposure to other ...                 X44
#
#       Deaths  Population  Crude Rate State_Code       County Name
# 0       20.0    179406.0     11.1479         AL    Baldwin County
# 1       18.0    182265.0  Unreliable         AL    Baldwin County
# 2       10.0    186717.0  Unreliable         AL    Baldwin County
# 3       12.0    186717.0  Unreliable         AL    Baldwin County
# 4       18.0    190790.0  Unreliable         AL    Baldwin County
# ...      ...         ...         ...        ...               ...
# 5244    11.0    168794.0  Unreliable         WI  Winnebago County
# 5245    12.0    169511.0  Unreliable         WI  Winnebago County
# 5246    13.0    169511.0  Unreliable         WI  Winnebago County
# 5247    11.0     94483.0  Unreliable         WY    Laramie County
# 5248    11.0     80973.0  Unreliable         WY    Natrona County
#
# [5249 rows x 12 columns]

# %%
vital["Cause of death"].value_counts()
# Out:
# Accidental poisoning by and exposure to other and unspecified drugs, medicaments and biological substances                                               2357
# Accidental poisoning by and exposure to narcotics and psychodysleptics [hallucinogens], not elsewhere classified                                         1810
# Intentional self-poisoning by and exposure to other and unspecified drugs, medicaments and biological substances                                          409
# Accidental poisoning by and exposure to antiepileptic, sedative-hypnotic, antiparkinsonism and psychotropic drugs, not elsewhere classified               217
# Poisoning by and exposure to other and unspecified drugs, medicaments and biological substances, undetermined intent                                      125
# Mental and behavioural disorders due to multiple drug use and use of other psychoactive substances, harmful use                                           102
# Poisoning by and exposure to narcotics and psychodysleptics [hallucinogens], not elsewhere classified, undetermined intent                                 94
# Intentional self-poisoning by and exposure to antiepileptic, sedative-hypnotic, antiparkinsonism and psychotropic drugs, not elsewhere classified          48
# Intentional self-poisoning by and exposure to narcotics and psychodysleptics [hallucinogens], not elsewhere classified                                     29
# Mental and behavioural disorders due to use of tobacco, unspecified mental and behavioural disorder                                                        17
# Mental and behavioural disorders due to use of opioids, harmful use                                                                                        14
# Mental and behavioural disorders due to use of opioids, unspecified mental and behavioural disorder                                                         6
# Mental and behavioural disorders due to use of other stimulants, including caffeine, harmful use                                                            5
# Mental and behavioural disorders due to use of cocaine, harmful use                                                                                         5
# Poisoning by and exposure to antiepileptic, sedative-hypnotic, antiparkinsonism and psychotropic drugs, not elsewhere classified, undetermined intent       4
# Mental and behavioural disorders due to multiple drug use and use of other psychoactive substances, dependence syndrome                                     4
# Accidental poisoning by and exposure to nonopioid analgesics, antipyretics and antirheumatics                                                               2
# Mental and behavioural disorders due to use of cocaine, unspecified mental and behavioural disorder                                                         1
# Name: Cause of death, dtype: int64

# %%
delete_cause = [
        "Mental and behavioural disorders due to use of tobacco, unspecified mental and behavioural disorder",
        "Mental and behavioural disorders due to use of cocaine, harmful use",
        "Mental and behavioural disorders due to use of cocaine, unspecified mental and behavioural disorder",
        "Intentional self-poisoning by and exposure to nonopioid analgesics, antipyretics and antirheumatics",
        "Accidental poisoning by and exposure to nonopioid analgesics, antipyretics and antirheumatics"
        ]

# %%
combining = [
    "Drug poisonings (overdose) Unintentional (X40-X44)",
    "Drug poisonings (overdose) Suicide (X60-X64)",
    "Drug poisonings (overdose) Undetermined (Y10-Y14)",
    "All other drug-induced causes",
    "Drug poisonings (overdose) Homicide (X85)",
]

# %%
vital_upd = vital[~vital["Cause of death"].isin(delete_cause)]
vital_upd
# Out:
#           State  State Code                County  County Code  Year  \
# 0       Alabama         1.0    Baldwin County, AL       1003.0  2009
# 1       Alabama         1.0    Baldwin County, AL       1003.0  2010
# 2       Alabama         1.0    Baldwin County, AL       1003.0  2011
# 3       Alabama         1.0    Baldwin County, AL       1003.0  2011
# 4       Alabama         1.0    Baldwin County, AL       1003.0  2012
# ...         ...         ...                   ...          ...   ...
# 5244  Wisconsin        55.0  Winnebago County, WI      55139.0  2012
# 5245  Wisconsin        55.0  Winnebago County, WI      55139.0  2014
# 5246  Wisconsin        55.0  Winnebago County, WI      55139.0  2014
# 5247    Wyoming        56.0    Laramie County, WY      56021.0  2012
# 5248    Wyoming        56.0    Natrona County, WY      56025.0  2013
#
#                                          Cause of death Cause of death Code  \
# 0     Accidental poisoning by and exposure to other ...                 X44
# 1     Accidental poisoning by and exposure to other ...                 X44
# 2     Accidental poisoning by and exposure to narcot...                 X42
# 3     Accidental poisoning by and exposure to other ...                 X44
# 4     Accidental poisoning by and exposure to other ...                 X44
# ...                                                 ...                 ...
# 5244  Accidental poisoning by and exposure to narcot...                 X42
# 5245  Accidental poisoning by and exposure to narcot...                 X42
# 5246  Accidental poisoning by and exposure to other ...                 X44
# 5247  Accidental poisoning by and exposure to other ...                 X44
# 5248  Accidental poisoning by and exposure to other ...                 X44
#
#       Deaths  Population  Crude Rate State_Code       County Name
# 0       20.0    179406.0     11.1479         AL    Baldwin County
# 1       18.0    182265.0  Unreliable         AL    Baldwin County
# 2       10.0    186717.0  Unreliable         AL    Baldwin County
# 3       12.0    186717.0  Unreliable         AL    Baldwin County
# 4       18.0    190790.0  Unreliable         AL    Baldwin County
# ...      ...         ...         ...        ...               ...
# 5244    11.0    168794.0  Unreliable         WI  Winnebago County
# 5245    12.0    169511.0  Unreliable         WI  Winnebago County
# 5246    13.0    169511.0  Unreliable         WI  Winnebago County
# 5247    11.0     94483.0  Unreliable         WY    Laramie County
# 5248    11.0     80973.0  Unreliable         WY    Natrona County
#
# [5224 rows x 12 columns]

# %%
states_control = pd.read_csv("../20_intermediate_files/states_control.csv", index_col=0)
states = list(states_control.States.unique())
states.remove('Alaska')
abbrv = ['CA','NV','NY','TX','HI','IA','KS','ME','MA','MN','MT','NE','ND','OR','SD','VA','WY','AR','GA','MS', 'FL', 'WA']

# %%
vital_upd_2 = vital_upd.loc[vital_upd["State_Code"].isin(abbrv),:]
vital_upd_2
# Out:
#            State  State Code              County  County Code  Year  \
# 241     Arkansas         5.0   Benton County, AR       5007.0  2009
# 242     Arkansas         5.0   Benton County, AR       5007.0  2010
# 243     Arkansas         5.0   Benton County, AR       5007.0  2011
# 244     Arkansas         5.0   Benton County, AR       5007.0  2012
# 245     Arkansas         5.0   Benton County, AR       5007.0  2013
# ...          ...         ...                 ...          ...   ...
# 5096  Washington        53.0   Yakima County, WA      53077.0  2010
# 5097  Washington        53.0   Yakima County, WA      53077.0  2012
# 5098  Washington        53.0   Yakima County, WA      53077.0  2014
# 5247     Wyoming        56.0  Laramie County, WY      56021.0  2012
# 5248     Wyoming        56.0  Natrona County, WY      56025.0  2013
#
#                                          Cause of death Cause of death Code  \
# 241   Accidental poisoning by and exposure to other ...                 X44
# 242   Accidental poisoning by and exposure to other ...                 X44
# 243   Accidental poisoning by and exposure to other ...                 X44
# 244   Accidental poisoning by and exposure to other ...                 X44
# 245   Accidental poisoning by and exposure to other ...                 X44
# ...                                                 ...                 ...
# 5096  Accidental poisoning by and exposure to other ...                 X44
# 5097  Accidental poisoning by and exposure to other ...                 X44
# 5098  Accidental poisoning by and exposure to other ...                 X44
# 5247  Accidental poisoning by and exposure to other ...                 X44
# 5248  Accidental poisoning by and exposure to other ...                 X44
#
#       Deaths  Population  Crude Rate State_Code     County Name
# 241     12.0    216620.0  Unreliable         AR   Benton County
# 242     12.0    221339.0  Unreliable         AR   Benton County
# 243     14.0    227556.0  Unreliable         AR   Benton County
# 244     14.0    232268.0  Unreliable         AR   Benton County
# 245     10.0    237297.0  Unreliable         AR   Benton County
# ...      ...         ...         ...        ...             ...
# 5096    19.0    243231.0  Unreliable         WA   Yakima County
# 5097    15.0    246977.0  Unreliable         WA   Yakima County
# 5098    12.0    247687.0  Unreliable         WA   Yakima County
# 5247    11.0     94483.0  Unreliable         WY  Laramie County
# 5248    11.0     80973.0  Unreliable         WY  Natrona County
#
# [2231 rows x 12 columns]

# %%
vital_upd_2.to_csv("../20_intermediate_files/vital_stats_WASHINGTON_merged.csv", encoding='utf-8')

# %%
vitalx = pd.read_csv('../20_intermediate_files/vital_stats_merged.csv')
